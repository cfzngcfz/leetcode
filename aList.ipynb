# %% [markdown]
# [CS-Notes/notes/Leetcode 题解](https://github.com/CyC2018/CS-Notes/blob/master/notes/Leetcode%20%E9%A2%98%E8%A7%A3%20-%20%E7%9B%AE%E5%BD%95.md)

# %% [markdown]
# - [X] [2. 两数相加](ListNode.ipynb#P.2)
# - [X] [3. 无重复字符的最长子串](SlidingWindow.ipynb#P.3)
# - [X] [5. 最长回文子串](DynamicProgramming.ipynb#P.5)
# - [X] [7. 整数反转](Unclassified.ipynb#P.7)
# - [X] [8. 字符串转换整数 (atoi)](Unclassified.ipynb#P.7)
# - [X] [10. 正则表达式匹配](DynamicProgramming.ipynb#P.10)
# - [x] [11. 盛最多水的容器](TwoPointers.ipynb#P.11)
# - [x] [15. 三数之和](TwoPointers.ipynb#P.15)
# - [X] [16. 最接近的三数之和](TwoPointers.ipynb#P.16)
# - [X] [17. 电话号码的字母组合](BackTrack.ipynb#P.17)
# - [X] [18. 四数之和](TwoPointers.ipynb#P.18)
# - [X] [19. 删除链表的倒数第 N 个结点](ListNode.ipynb#P.19)
# - [X] [20. 有效的括号](Stack.ipynb#P.20)
# - [X] [21. 合并两个有序链表](ListNode.ipynb#P.21)
# - [X] [22. 括号生成](BackTrack.ipynb#P.22)
# - [X] [23. 合并 K 个升序链表](ListNode.ipynb#P.23)
# - [X] [24. 两两交换链表中的节点](ListNode.ipynb#P.24)
# - [X] [25. K 个一组翻转链表](ListNode.ipynb#P.25)
# - [X] [31. 下一个排列](BackTrack.ipynb#P.31)
# - [X] [32. 最长有效括号](DynamicProgramming.ipynb#P.32)
# - [X] [34. 在排序数组中查找元素的第一个和最后一个位置](Unclassified.ipynb#P.34)
# - [X] [35. 搜索插入位置](Unclassified.ipynb#P.35)
# - [X] [37. 解数独](BackTrack.ipynb#P.37)
# - [X] [39. 组合总和](BackTrack.ipynb#P.39)
# - [ ] [40. 组合总和 II](BackTrack.ipynb#P.40)
# - [X] [42. 接雨水](DynamicProgramming.ipynb#P.42)
# - [X] [43. 字符串相乘](Unclassified.ipynb#P.43)
# - [X] [44. 通配符匹配](DynamicProgramming.ipynb#P.44)
# - [X] [45. 跳跃游戏 II](Greedy.ipynb#P.45)
# - [X] [46. 全排列](BackTrack.ipynb#P.46)
# - [X] [47. 全排列 II](BackTrack.ipynb#P.47)
# - [ ] [50. Pow(x, n)](BackTrack.ipynb#P.50)
# - [X] [51. N 皇后](BackTrack.ipynb#P.51)
# - [X] [52. N 皇后 II](BackTrack.ipynb#P.52)
# - [X] [53. 最大子数组和](DynamicProgramming.ipynb#P.53)
# - [X] [55. 跳跃游戏](Greedy.ipynb#P.55)
# - [X] [61. 旋转链表](ListNode.ipynb#P.61)
# - [X] [62. 不同路径](DynamicProgramming.ipynb#P.62)
# - [X] [63. 不同路径 II](DynamicProgramming.ipynb#P.63)
# - [X] [64. 最小路径和](DynamicProgramming.ipynb#P.64)
# - [X] [69. x 的平方根 ](Unclassified#P.69)
# - [X] [70. 爬楼梯](DynamicProgramming.ipynb#P.70)
# - [X] [75. 颜色分类](Sort.ipynb#P.75)
# - [X] [77. 组合](BackTrack.ipynb#P.77)
# - [X] [78. 子集](BackTrack.ipynb#P.78)
# - [X] [82. 删除排序链表中的重复元素 II](ListNode.ipynb#P.82)
# - [X] [83. 删除排序链表中的重复元素](ListNode.ipynb#P.83)
# - [X] [90. 子集 II](BackTrack.ipynb#P.90)
# - [X] [91. 解码方法](DynamicProgramming.ipynb#P.91)
# - [X] [92. 反转链表 II](ListNode.ipynb#P.92)
# - [ ] [93. 复原 IP 地址](BackTrack.ipynb#P.93)
# - [X] [94. 二叉树的中序遍历](TreeNode.ipynb#P.94)
# - [ ] [101. 对称二叉树](TreeNode.ipynb#P.101)
# - [X] [102. 二叉树的层序遍历](TreeNode.ipynb#P.102)
# - [X] [104. 二叉树的最大深度](TreeNode.ipynb#P.104)
# - [ ] [110. 平衡二叉树](TreeNode.ipynb#P.110)
# - [X] [112. 路径总和](TreeNode.ipynb#P.112)
# - [X] [113. 路径总和 II](TreeNode.ipynb#P.113)
# - [X] [118. 杨辉三角](DynamicProgramming.ipynb#P.118)
# - [ ] [119. 杨辉三角 II](DynamicProgramming.ipynb#P.119)
# - [X] [120. 三角形最小路径和](DynamicProgramming.ipynb#P.120)
# - [ ] [129. 求根节点到叶节点数字之和](TreeNode.ipynb#P.129)
# - [X] [139. 单词拆分](DynamicProgramming.ipynb#P.139)
# - [X] [140. 单词拆分 II](BackTrack.ipynb#P.140)
# - [X] [144. 二叉树的前序遍历](TreeNode.ipynb#P.144)
# - [X] [145. 二叉树的后序遍历](TreeNode.ipynb#P.145)
# - [X] [198. 打家劫舍](DynamicProgramming.ipynb#P.198)
# - [X] [206. 反转链表](ListNode.ipynb#P.206)
# - [X] [213. 打家劫舍 II](DynamicProgramming.ipynb#P.213)
# - [X] [216. 组合总和 III](BackTrack.ipynb#P.216)
# - [X] [224. 基本计算器](Stack.ipynb#P.224)
# - [X] [227. 基本计算器 II](Stack.ipynb#P.227)
# - [X] [239. 滑动窗口最大值](Sort.ipynb#P.227)
# - [X] [279. 完全平方数](DynamicProgramming.ipynb#P.279)
# - [X] [322. 零钱兑换](DynamicProgramming.ipynb#P.322)
# - [X] [377. 组合总和 Ⅳ](DynamicProgramming.ipynb#P.377)
# - [X] [416. 分割等和子集](DynamicProgramming.ipynb#P.416)
# - [X] [437. 路径总和 III](TreeNode.ipynb#P.437)
# - [X] [454. 四数相加 II](TwoPointers.ipynb#P.454)
# - [X] [518. 零钱兑换 II](DynamicProgramming.ipynb#P.518)
# - [X] 561\. 数组拆分
# - [ ] [563. 二叉树的坡度](TreeNode.ipynb#P.563)
# - [X] [589. N 叉树的前序遍历](TreeNode.ipynb#P.589)
# - [X] [590. N 叉树的后序遍历](TreeNode.ipynb#P.590)
# - [X] [704. 二分查找](Unclassified.ipynb#P.704)
# - [X] [746. 使用最小花费爬楼梯](DynamicProgramming.ipynb#P.746)
# - [X] [1222. 可以攻击国王的皇后](BackTrack.ipynb#P.1222)
# - [X] [1306. 跳跃游戏 III](Greedy.ipynb#P.1306)
# - [X] [1654. 到家的最少跳跃次数](Greedy.ipynb#P.1654)
# - [X] [1696. 跳跃游戏 VI](Greedy.ipynb#P.1696)
# - [X] [3001. 捕获黑皇后需要的最少移动次数](BackTrack.ipynb#P.3001)
# - [X] [剑指 Offer 24. 反转链表](ListNode.ipynb#Offer.24)
# - [X] [剑指 Offer 34. 二叉树中和为某一值的路径](TreeNode.ipynb#Offer.34)
# - [X] [剑指 Offer II 024. 反转链表](ListNode.ipynb#Offer.II024)
# - [ ] [剑指 Offer II 049. 从根节点到叶节点的路径数字之和](TreeNode.ipynb#Offer.II049)
# - [ ] [剑指 Offer II 050. 向下的路径节点之和](TreeNode.ipynb#Offer.II050)
# - [X] [LCR 007. 三数之和](TwoPointers.ipynb#LCR.007)
# - [X] [LCR 021. 删除链表的倒数第 N 个结点](ListNode.ipynb#LCR.021)
# - [X] [LCR 072. x 的平方根](Unclassified.ipynb#LCR.072)
# - [X] [LCR 079. 子集](BackTrack.ipynb#LCR.079)
# - [X] [LCR 081. 组合总和](BackTrack.ipynb#LCR.081)
# - [X] [LCR 082. 组合总和 II](BackTrack.ipynb#LCR.082)
# - [X] [LCR 089. 打家劫舍](DynamicProgramming.ipynb#LCR.089)
# - [X] [LCR 090. 打家劫舍 II](DynamicProgramming.ipynb#LCR.090)
# - [X] [LCR 099. 最小路径和](DynamicProgramming.ipynb#LCR.099)
# - [X] [LCR 100. 三角形最小路径和](DynamicProgramming.ipynb#LCR.100)
# - [X] [LCR 101. 分割等和子集](DynamicProgramming.ipynb#LCR.101)
# - [X] [LCR 103. 零钱兑换](DynamicProgramming.ipynb#LCR.103)
# - [X] [LCR 127. 跳跃训练](DynamicProgramming.ipynb#LCR.127)
# - [X] [LCR 137. 模糊搜索验证](DynamicProgramming.ipynb#LCR.137)
# - [X] [LCR 161. 连续天数的最高销售额](DynamicProgramming.ipynb#LCR.161)
# - [X] [LCR 165. 解密数字](DynamicProgramming.ipynb#LCR.165)
# - [X] [LCR 175. 计算二叉树的深度](TreeNode.ipynb#LCR.175)
# - [X] [LCR 176. 判断是否为平衡二叉树](TreeNode.ipynb#P.110)
# - [X] [面试题 02.04. 分割链表](ListNode.ipynb#ms.02.04)
# - [X] [面试题 08.12. 八皇后](BackTrack.ipynb#ms.08.12)

# %% [markdown]
# # todo
# - [ ] [29. 两数相除](BackTrack.ipynb#P.29)
# - [ ] [770. 基本计算器 IV](Stack.ipynb#P.770)
# - [ ] [1871. 跳跃游戏 VII](https://leetcode.cn/problems/jump-game-vii/) 前缀和优化
#
# index | problem
# :- | :-:
# 4.对称二叉树 | Done
# 5.平衡二叉树 | Done
# 6.多数元素 | Done
# 8.用栈实现队列 | Done
# 9.字符串相加 | Done
# 10.二分查找 | Done
# 11.无重复字符的最长子串
# 12.最长回文子串 | Done
# 14.两两交换链表中的节点 | Done
# 16.分割链表 | Done
# 18.求根到叶子节点数字之和 | Done
# 19.复制带随机指针的链表
# 20.二叉树的后序遍历 | Done
# 21.LRU缓存机制 | [146. LRU 缓存](https://leetcode.cn/problems/lru-cache/)
# 22.最大和 | Done
# 23.寻找重复数 | Done
# 24.递增的三元子序列 | [递增的三元子序列](https://leetcode.cn/problems/increasing-triplet-subsequence/)
# 25.常数时间插入，删除和获取随。。。| [380. O(1) 时间插入、删除和获取随机元素](https://leetcode.cn/problems/insert-delete-getrandom-o1/)<br>[381. O(1) 时间插入、删除和获取随机元素 - 允许重复](https://leetcode.cn/problems/insert-delete-getrandom-o1-duplicates-allowed/)
# 26.验证IP 地址 | Done
# 27.有序数组中的单一元素 | Done
# 28.和为K 的子数组 | [560. 和为 K 的子数组](https://leetcode.cn/problems/subarray-sum-equals-k/)
# 29.平方数之和 | Done
# 30.最长有效括号
# 31.柱状图中最大的矩形
# 32.至少有1位重复数字

# %% [markdown]
# - [ ] nms算法实现（高频）
#     - https://blog.csdn.net/weixin_64043217/article/details/132508229
# - [X] 判断一个数是否为素数
# - [ ] KMeans算法（高频出现）
# - [X] topk 算法（变种题目：限制不能用大小堆写，要用快排写）
# - [X] 快速排序
# - [ ] 求连通域的最大长度
# - [ ] anchors和gt的fasterrcnn的labelasign
# - [X] 数组能否分为和相等的两个子集
#     - https://leetcode.cn/problems/partition-to-k-equal-sum-subsets/description/
#     - https://leetcode.cn/problems/QTMn0o/description/
#     - https://leetcode.cn/problems/subarray-sum-equals-k/description/
#     - https://leetcode.cn/problems/partition-array-into-three-parts-with-equal-sum/description/
#     - https://leetcode.cn/problems/find-subarrays-with-equal-sum/description/
#     - https://leetcode.cn/problems/make-k-subarray-sums-equal/description/

# %%
# nms算法实现
import numpy as np
#假设生成9个候选框
boxes = np.array([[100,100,210,210,0.72],
                 [250,25,420,420,0.87],
                 [220,220,320,330,0.92],
                 [120,130,210,210,0.73],
                 [230,240,325,330,0.81],
                 [220,230,315,340,0.93],
                 [300,400,450,220,0.95],
                 [200,150,500,100,0.85],
                 [350,450,500,270,0.78]
                 ])
 
 
 
 
def nms(bboxes,thresh):
 
    x1 = bboxes[:, 0]
    y1 = bboxes[:, 1]
    x2 = bboxes[:, 2]
    y2 = bboxes[:, 3]
 
    areas = (x2 - x1 + 1) * (y2 - y1 + 1)
       #进行排序
 
 
 
    scores = bboxes[:, 4]
    index = scores.argsort()[::-1]
 
    res = []
    while index.size > 0:
        print(" ------------ ")
        print("index = ", index, ", len = ", len(index))
        i = index[0]
        print("i = ", i)
        res.append(i)
 
        X1 = np.maximum(x1[i],x1[index[1:]])
        Y1 = np.maximum(y1[i],y1[index[1:]])
        X2 = np.minimum(x2[i],x2[index[1:]])
        Y2 = np.minimum(y2[i],y2[index[1:]])
 
        w = np.maximum(0, X2 - X1 + 1)
        h = np.maximum(0, Y2 - Y1 + 1)
 
        jiao = w*h
        iou = jiao / (areas[i] + areas[index[1:]] - jiao)
        print("iou = ", iou, ", len = ", len(iou))
 
        idx = np.where(iou <= thresh)[0]
        print("idx = ", idx, ", len = ", len(idx))
        index = index[idx + 1]
        print("index = ", index, ", len = ", len(index))
 
 
    return res

 
# 使用示例
nms_result = nms(boxes, thresh=0.5)
print(" ---- output ----")
print(nms_result)
# Out:
#  ------------
# index =  [6 5 2 1 7 4 8 3 0] , len =  9
# i =  6
# iou =  [-0. -0.  0. -0. -0. -0. -0. -0.] , len =  8
# idx =  [0 1 2 3 4 5 6 7] , len =  8
# index =  [5 2 1 7 4 8 3 0] , len =  8
#  ------------
# index =  [5 2 1 7 4 8 3 0] , len =  8
# i =  5
# iou =  [ 0.79664777  0.10311629 -0.          0.67663842 -0.          0.
#   0.        ] , len =  7
# idx =  [1 2 4 5 6] , len =  5
# index =  [1 7 8 3 0] , len =  5
#  ------------
# index =  [1 7 8 3 0] , len =  5
# i =  1
# iou =  [0. 0. 0. 0.] , len =  4
# idx =  [0 1 2 3] , len =  4
# index =  [7 8 3 0] , len =  4
#  ------------
# index =  [7 8 3 0] , len =  4
# i =  7
# iou =  [-0. -0. -0.] , len =  3
# idx =  [0 1 2] , len =  3
# index =  [8 3 0] , len =  3
#  ------------
# index =  [8 3 0] , len =  3
# i =  8
# iou =  [-0. -0.] , len =  2
# idx =  [0 1] , len =  2
# index =  [3 0] , len =  2
#  ------------
# index =  [3 0] , len =  2
# i =  3
# iou =  [0.5982469] , len =  1
# idx =  [] , len =  0
# ...

# %%
# k-means
import numpy as np
from matplotlib import pyplot


class K_Means(object):
    # k是分组数；tolerance‘中心点误差’；max_iter是迭代次数
    def __init__(self, k=2, tolerance=0.0001, max_iter=300):
        self.k_ = k
        self.tolerance_ = tolerance
        self.max_iter_ = max_iter

    def fit(self, data):
        print("data = ", data)
        self.centers_ = {}
        for i in range(self.k_):
            self.centers_[i] = data[i]
        print("centers = ", self.centers_ )
        
        for i in range(self.max_iter_):
            print("-------------- loop: " + str(i) + "--------------")
            self.clf_ = {}
            for i in range(self.k_):
                self.clf_[i] = []
            # print("质点:",self.centers_)
            for feature in data:
                # distances = [np.linalg.norm(feature-self.centers[center]) for center in self.centers]
                distances = []
                for center in self.centers_:
                    # 欧拉距离
                    # np.sqrt(np.sum((features-self.centers_[center])**2))
                    distances.append(np.linalg.norm(feature - self.centers_[center]))
                classification = distances.index(min(distances))
                self.clf_[classification].append(feature)

            print("分组情况:",self.clf_)
            prev_centers = dict(self.centers_)
            for c in self.clf_:
                self.centers_[c] = np.average(self.clf_[c], axis=0)
            
            print("prev centers = ", prev_centers)
            print("cur centers = ", self.centers_)
            # '中心点'是否在误差范围
            optimized = True
            for center in self.centers_:
                org_centers = prev_centers[center]
                cur_centers = self.centers_[center]
                print("center = ", center, ", org_centers = ", org_centers, ", cur_centers = ", cur_centers, ", left = ", np.sum((cur_centers - org_centers) / org_centers * 100.0))
                if np.sum((cur_centers - org_centers) / org_centers * 100.0) > self.tolerance_: 
                    optimized = False
            if optimized:
                break

    def predict(self, p_data):
        distances = [np.linalg.norm(p_data - self.centers_[center]) for center in self.centers_]
        index = distances.index(min(distances))
        return index


if __name__ == '__main__':
    x = np.array([[1, 2], [1.5, 1.8], [5, 8], [8, 8], [1, 0.6], [9, 11]])
    k_means = K_Means(k=2)
    k_means.fit(x)
    print(k_means.centers_)
    for center in k_means.centers_:
        pyplot.scatter(k_means.centers_[center][0], k_means.centers_[center][1], marker='*', s=150)

    for cat in k_means.clf_:
        for point in k_means.clf_[cat]:
            pyplot.scatter(point[0], point[1], c=('r' if cat == 0 else 'b'))

    predict = [[2, 1], [6, 9]]
    for feature in predict:
        cat = k_means.predict(predict)
        pyplot.scatter(feature[0], feature[1], c=('r' if cat == 0 else 'b'), marker='x')

    pyplot.show()
# Out:
# data =  [[ 1.   2. ]
#  [ 1.5  1.8]
#  [ 5.   8. ]
#  [ 8.   8. ]
#  [ 1.   0.6]
#  [ 9.  11. ]]
# centers =  {0: array([1., 2.]), 1: array([1.5, 1.8])}
# -------------- loop: 0--------------
# 分组情况: {0: [array([1., 2.])], 1: [array([1.5, 1.8]), array([5., 8.]), array([8., 8.]), array([1. , 0.6]), array([ 9., 11.])]}
# prev centers =  {0: array([1., 2.]), 1: array([1.5, 1.8])}
# cur centers =  {0: array([1., 2.]), 1: array([4.9 , 5.88])}
# center =  0 , org_centers =  [1. 2.] , cur_centers =  [1. 2.] , left =  0.0
# center =  1 , org_centers =  [1.5 1.8] , cur_centers =  [4.9  5.88] , left =  453.3333333333334
# -------------- loop: 1--------------
# 分组情况: {0: [array([1., 2.]), array([1.5, 1.8]), array([1. , 0.6])], 1: [array([5., 8.]), array([8., 8.]), array([ 9., 11.])]}
# prev centers =  {0: array([1., 2.]), 1: array([4.9 , 5.88])}
# cur centers =  {0: array([1.16666667, 1.46666667]), 1: array([7.33333333, 9.        ])}
# ...

# %%
# 判断一个数是否为素数/质数
num = 7
def is_prime(num):
    if num < 2:
        return False
    for ii in range(2, int(num**0.5) + 1):
        if num % ii == 0:
            return False
    return True

for ii in range(20):
    print(ii, "is prime?", is_prime(ii))
# Out:
# 0 is prime? False
# 1 is prime? False
# 2 is prime? True
# 3 is prime? True
# 4 is prime? False
# 5 is prime? True
# 6 is prime? False
# 7 is prime? True
# 8 is prime? False
# 9 is prime? False
# 10 is prime? False
# 11 is prime? True
# 12 is prime? False
# 13 is prime? True
# 14 is prime? False
# 15 is prime? False
# 16 is prime? False
# 17 is prime? True
# 18 is prime? False
# 19 is prime? True

# %% [markdown]
# - 质数/素数
#     - [1175. 质数排列](https://leetcode.cn/problems/prime-arrangements/)
#     - [204. 计数质数](https://leetcode.cn/problems/count-primes/)
#     - [866. 回文质数](https://leetcode.cn/problems/prime-palindrome/)
#     - [2601. 质数减法运算](https://leetcode.cn/problems/prime-subtraction-operation/)
#     - [2614. 对角线上的质数](https://leetcode.cn/problems/prime-in-diagonal/)
#     - [3115. 质数的最大距离](https://leetcode.cn/problems/maximum-prime-difference/)
#     - [3044. 出现频率最高的质数](https://leetcode.cn/problems/most-frequent-prime/)
#     - [2761. 和等于目标值的质数对](https://leetcode.cn/problems/prime-pairs-with-target-sum/)
#     - [2523. 范围内最接近的两个质数](https://leetcode.cn/problems/prime-number-of-set-bits-in-binary-representation/)
# - 丑数
#     - [263. 丑数](https://leetcode.cn/problems/ugly-number/)
#     - [264. 丑数 II](https://leetcode.cn/problems/ugly-number-ii/) $\iff$ [LCR 168. 丑数](https://leetcode.cn/problems/chou-shu-lcof/)
#     - [1201. 丑数 III](https://leetcode.cn/problems/ugly-number-iii/)
#     - [313. 超级丑数](https://leetcode.cn/problems/super-ugly-number/)
